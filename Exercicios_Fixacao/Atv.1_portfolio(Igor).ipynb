# %% [markdown]
# <a href="https://colab.research.google.com/github/engenhariasigor-dev/ALGESTDADOS20261/blob/main/Exercicios_Fixacao/Atv.1_portfolio(Igor).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Oi Mundo")
# Out:
# olá mundo

# %%
print("tchau mudo")
# Out:
# tchau mudin
