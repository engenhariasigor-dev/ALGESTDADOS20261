# %% [markdown]
# <a href="https://colab.research.google.com/github/engenhariasigor-dev/ALGESTDADOS20261/blob/main/Exercicios_Fixacao/Atv_4_portfolio_(Igor).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 Declare duas variáveis a = 15 e b = 4. Calcule e exiba o resultado de todas as operações aritméticas: +, -, *, /, //, % e **.
a= 15
b= 4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %%
#2 Um professor deseja dividir 37 alunos em grupos iguais de 5. Usando operadores aritméticos, descubra: quantos grupos completos serão formados e quantos alunos sobrarão
a= 37
g= 5
print(a//b)
print(a%b)
# Out:
# 9
# 1

# %%
#3 Calcule a área de um retângulo com base 8.5 e altura 3.2. Exiba o resultado com a mensagem: A área do retângulo é: X
B= 8.5
H= 3.2
print(f"A área deste retângulo é {B*H:.2f}")
# Out:
# A área deste retângulo é 27.20

# %%
#4 Dado o valor: segundos = 9875 :Use // e % para converter esse valor em horas, minutos e segundos. Exemplo de saída: 2h 44min 35seg
seg= 9875%60
min= (9875//60) % 60
hor= 9875//(60*60)
print(hor,'h',min,'m',seg,'s')
# Out:
# 2 h 44 m 35 s

# %%
#5 Calcule: 2 ** 10 :Explique com um comentário no código o que essa operação representa. Depois calcule a raiz quadrada de 144 usando potenciação.
print(f'Sendo uma certa potenciação, dois elevado a dez, sendo dois a base e dez o expoente, teremos: 2^10 = {2**10}')
# Out:
# Sendo uma certa potenciação, dois elevado a dez, sendo dois a base e dez o expoente, teremos: 2^10 = 1024

# %%
#6 Crie uma variável: temperatura = 38.5 :Use operadores relacionais para verificar: se a temperatura é maior que 37.5 :se a temperatura é igual a 36.5 :se a temperatura é diferente de 40.0
Temp= 38.5
print(Temp > 37.5)
print(Temp == 36.5)
print(Temp != 40)
# Out:
# True
# False
# True

# %%
#7 Dados: x = 10 e y = 10 :Preveja o resultado antes de executar e depois confirme no Python: x==y x!=y x>=y x<=y+1
x = 10
y = 10
print(x == y)
print(x != y)
print(x >= y)
print(x <= y + 1)
# Out:
# True
# False
# True
# True

# %%
#8 Um aluno tirou nota 6.5. Usando operadores relacionais, verifique se ele: foi aprovado; está em recuperação; foi reprovado
nota= 6.5
print(nota >= 7.0)
print(nota >= 5.0 and nota < 7.0)
print(nota < 5.0)
# Out:
# False
# True
# False

# %%
#9 Declare: a = 5 b = "5" :Compare: (a == b) :Explique o resultado com um comentário no código.
a = 5
b = "5"
a == b
# O resultado é False porque comparamos um int (inteiro) com uma str (texto)
# Out:
# False

# %%
#10 Crie um programa com: preço = 49.90 :Verifique se o produto está dentro do orçamento de R$ 50,00 usando <=
preço = 49.90
orça = 50
print(preço<=orça)
# Out:
# True

# %%
#11 Uma pessoa pode votar se tiver 16 anos ou mais: idade = 15 :Use operadores lógicos para verificar se ela não pode votar. Depois teste com: idade = 18
idade = 15
print(idade>=16)
idade = 18
print(idade>=18)
# Out:
# False
# True

# %%
#12 Um empréstimo é aprovado se: renda >= 2000 e score >= 700 :Teste pelo menos três combinações diferentes usando and.
renda= 900
score= 666
print(f"Teste 1: {renda>=2000 and score>= 700}")
renda= 1621
score= 369
print(f"Teste 2: {renda>=2000 and score>= 700}")
renda= 10000
score= 3500
print(f"Teste 3: {renda>=2000 and score>= 700}")
# Out:
# Teste 1: False
# Teste 2: False
# Teste 3: True

# %%
#13 Um sistema libera acesso se o usuário for administrador ou tiver nível de acesso ≥ 3.
is_admin = False
nivel_acesso = 4
acesso_liberado = is_admin or nivel_acesso >= 3
print(f"Acesso liberado: {acesso_liberado}")
# Out:
# Acesso liberado: True

# %%
#14 Dado: chovendo = True :Use not para verificar se não está chovendo. Depois combine com uma verificação de temperatura maior que 25.
chovendo = True
Temp= 67
print(f'Está chovendo? {not chovendo} \n Temperatura é maior que 25°C? {Temp>25}')
# Out:
# Está chovendo? False
#  Temperatura é maior que 25°C? True

# %%
#15 Monte manualmente a tabela-verdade do operador and: True and True True and False False and True False and False
print('A tabela-verdadedo operador "AND" (E)')
print(f'True and True = {True and True}')
print(f'True and False = {True and False}')
print(f'False and True = {False and True}')
print(f'False and False {False and False}')
# Out:
# A tabela-verdadedo operador "AND" (E)
# True and True = True
# True and False = False
# False and True = False
# False and False False

# %%
#16 Calcule manualmente antes de executar: 5 + 2 * 3; (5 + 2) * 3; 2 ** 3 ** 2; 10 - 4 / 2 + 1 :Explique a ordem de execução nos comentários.
R1= 5 + 2 * 3 #Multiplicação tem precedência sobre a adição
R2= (5 + 2) * 3 #Parênteses forçam a execução da adição primeiro
R3= 2 ** 3 ** 2 #Potência (**) é executada da direita para a esquerda em Python
R4= 10 - 4 / 2 + 1 #Divisão primeiro (gera float), depois as somas/subtrações da esquerda para a direita

# %%
#17 Resolva passo a passo: resultado = 3 + 2 * 4 ** 2 - 1 :Reescreva usando parênteses para mostrar a ordem das operações.
B = 3 + 2 * 4 ** 2 - 1
print('4**2 = 16')
print('16*2 = 32')
print('32+3-1 = 34')
R = 3 + (2 * (4 ** 2)) - 1
print(R==B)
# Out:
# 4**2 = 16
# 16*2 = 32
# 32+3-1 = 34
# True

# %%
#18 Analise o resultado da expressão abaixo antes de executar: x = 4 + 3 * 2 > 9 and not (5 == 5)
x = 4 + 3 * 2 > 9
y = 5 == 5
print(x,y)
x and not y
# Out:
# True True
# False

# %%
#19 Reescreva usando parênteses para obter os resultados indicados: 10 / 2 + 3 #Resultado = 2 : not True or False #Resultado = False
print(10 / (2 + 3)) #Resultado = 2
print(not(True or False)) #Resultado = False
# Out:
# 2.0
# False

# %%
#20 Crie uma expressão que use operadores aritméticos, relacionais e lógicos para resolver o problema: Um estudante é aprovado com distinção se a média de duas notas for maior ou igual a 9.0 e nenhuma das notas for menor que 7.0. : nota1 = 9.5  :nota2 = 8.5
n1 = 9.5
n2 = 8.5
med = (n1+n2)/2
aprov = n1 > 7.0 and n2 > 7.0
dist = med >= 9.0 and aprov
print(f'Está Aprovado? {dist}')
# Out:
# Está Aprovado? True
