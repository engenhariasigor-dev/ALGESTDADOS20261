# %% [markdown]
# <a href="https://colab.research.google.com/github/engenhariasigor-dev/ALGESTDADOS20261/blob/main/test/Atv_1_portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Oi Mundo")
# Out:
# olá mundo

# %%
print("tchau mudin")
# Out:
# tchau mudin
